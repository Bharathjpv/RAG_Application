# %%
MODEL = 'llama3'

# %% [markdown]
# ## Load model

# %%
from langchain_community.llms import Ollama

model = Ollama(model = MODEL, top_k=128)
print(model.invoke("Tell me a joke about scientists"))
# Out:
# Why did the scientist take out his doorbell?
#
# Because he wanted to see some "experimental" results!

# %% [markdown]
# ## Parser

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

chain = model | parser
chain.invoke("What MLB team won the World Series during the COVID-19 pandemic?")
# Out:
# 'The Los Angeles Dodgers won the 2020 World Series, which was played during the COVID-19 pandemic. The series was played from October 5 to October 27, 2020, and the Dodgers defeated the Tampa Bay Rays in six games (4-2). This was their first World Series title since 1988.'

# %% [markdown]
# ## Prompt templete

# %%
from langchain.prompts import ChatPromptTemplate

template = """
Answer the question based on the context below no need to explain the results. If you can't 
answer the question, reply "I don't know".

Context: {context}

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
print(prompt.format(context="Mary's sister is Susana", question="Who is Mary's sister?"))
# Out:
# Human:
# Answer the question based on the context below no need to explain the results. If you can't
# answer the question, reply "I don't know".
#
# Context: Mary's sister is Susana
#
# Question: Who is Mary's sister?

# %%
chain = prompt | model | parser
chain.invoke({
    "context": "Mary's sister is Susana",
    "question": "Who is Mary's sister?"
})
# Out:
# 'Susana'

# %% [markdown]
# ## Combination chains

# %%
translation_prompt = ChatPromptTemplate.from_template(
    "Translate {answer} to {language}"
)

# %%
from operator import itemgetter

translation_chain = (
    {"answer": chain, "language": itemgetter("language")} | translation_prompt | model | parser
)

print(translation_chain.invoke(
    {
        "context": "Mary's sister is Susana. She doesn't have any more siblings.",
        "question": "How many sisters does Mary have and what is her name?",
        "language": "Spanish",
    }
))
# Out:
# The translation of "Sister" in this context is "Hermana".
#
# So, the correct translation would be:
#
# 1 hermana: Susana -> Una hermana llamada Susana (One sister named Susana)

# %% [markdown]
# ## Transcribing youtube video

# %%
import os
import tempfile
import whisper
from pytube import YouTube

# This is the YouTube video we're going to use.
YOUTUBE_VIDEO = "https://www.youtube.com/watch?v=cdiD-9MMpb0"

# Let's do this only if we haven't created the transcription file yet.
if not os.path.exists("transcription.txt"):
    youtube = YouTube(YOUTUBE_VIDEO)
    audio = youtube.streams.filter(only_audio=True).first()

    # Let's load the base model. This is not the most accurate
    # model but it's fast.
    whisper_model = whisper.load_model("base")

    with tempfile.TemporaryDirectory() as tmpdir:
        file = audio.download(output_path=tmpdir)
        transcription = whisper_model.transcribe(file, fp16=False)["text"].strip()

        with open("transcription.txt", "w") as file:
            file.write(transcription)

# %%
with open("transcription.txt") as file:
    transcription = file.read()

transcription[:100]
# Out:
# "I think it's possible that physics has exploits and we should be trying to find them. arranging some"

# %% [markdown]
# ## Entire transcription as context

# %%
try:
    print(chain.invoke({
        "context": transcription,
        "question": "Is reading papers a good idea?"
    }))
except Exception as e:
    print(e)
# Out:
# According to Andre Karpathy, reading papers can be an interesting experience when AI-generated content becomes more prevalent. He mentions that if the cost of content creation falls to zero, Hollywood might start using AI to generate scenes, which could open up new possibilities for creating movies like Avatar for under a million dollars or even just by talking to your phone. He also thinks that generating synthetic content could be humbling, as humans tend to treat themselves as special for being able to create art and ideas.

# %% [markdown]
# ## Text Splitter

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader('transcription.txt')
text_documents = loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size = 100, chunk_overlap=20)
text_splitter.split_documents(text_documents)
# Out:
# [Document(page_content="I think it's possible that physics has exploits and we should be trying to find them. arranging some", metadata={'source': 'transcription.txt'}),
#  Document(page_content='arranging some kind of a crazy quantum mechanical system that somehow gives you buffer overflow,', metadata={'source': 'transcription.txt'}),
#  Document(page_content='buffer overflow, somehow gives you a rounding error in the floating point. Synthetic intelligences', metadata={'source': 'transcription.txt'}),
#  Document(page_content="intelligences are kind of like the next stage of development. And I don't know where it leads to.", metadata={'source': 'transcription.txt'}),
#  Document(page_content='where it leads to. Like at some point, I suspect the universe is some kind of a puzzle. These', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of a puzzle. These synthetic AIs will uncover that puzzle and solve it. The following is a', metadata={'source': 'transcription.txt'}),
#  Document(page_content='The following is a conversation with Andre Kappathi, previously the director of AI at Tesla. And', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of AI at Tesla. And before that, at OpenAI and Stanford, he is one of the greatest scientist', metadata={'source': 'transcription.txt'}),
#  Document(page_content='greatest scientist engineers and educators in the history of artificial intelligence. This is the', metadata={'source': 'transcription.txt'}),
#  Document(page_content='This is the Lex Friedman podcast to support it. Please check out our sponsors and now to your', metadata={'source': 'transcription.txt'}),
#  Document(page_content="and now to your friends. Here's Andre Kappathi. What is a neural network? And what does it seem to", metadata={'source': 'transcription.txt'}),
#  Document(page_content="does it seem to do such a surprisingly good job of learning? What is a neural network? It's a", metadata={'source': 'transcription.txt'}),
#  Document(page_content="network? It's a mathematical abstraction of the brain. I would say that's how it was originally", metadata={'source': 'transcription.txt'}),
#  Document(page_content="it was originally developed. At the end of the day, it's a mathematical expression. And it's a", metadata={'source': 'transcription.txt'}),
#  Document(page_content="And it's a fairly simple mathematical expression when you get down to it. It's basically a sequence", metadata={'source': 'transcription.txt'}),
#  Document(page_content='a sequence of meter smoke applies, whichever link dot products mathematically. And some', metadata={'source': 'transcription.txt'}),
#  Document(page_content="And some non-linearities throw them in. And so it's a very simple mathematical expression. And it's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="And it's got knobs in it. Many knobs. Many knobs. And these knobs are loosely related to basically", metadata={'source': 'transcription.txt'}),
#  Document(page_content="to basically the synapses in your brain. They're trainable, they're modifiable. And so the idea is", metadata={'source': 'transcription.txt'}),
#  Document(page_content='And so the idea is we need to find the setting of the knobs that makes the neural net do whatever', metadata={'source': 'transcription.txt'}),
#  Document(page_content="net do whatever you want it to do, like classify images and so on. And so there's not too much", metadata={'source': 'transcription.txt'}),
#  Document(page_content="not too much mystery I would say in it. Like you might think that basically don't want to end out", metadata={'source': 'transcription.txt'}),
#  Document(page_content="want to end out with too much meaning with respect to the brain and how it works. It's really just", metadata={'source': 'transcription.txt'}),
#  Document(page_content="It's really just a complicated mathematical expression with knobs. And those knobs need a proper", metadata={'source': 'transcription.txt'}),
#  Document(page_content='knobs need a proper setting for it to do something desirable. Yeah, but poetry is just the', metadata={'source': 'transcription.txt'}),
#  Document(page_content='poetry is just the collection of letters with spaces. But it can make us feel a certain way. And in', metadata={'source': 'transcription.txt'}),
#  Document(page_content="certain way. And in that same way, when you get a large number of knobs together, whether it's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="whether it's inside the brain or inside a computer, they seem to they seem to surprise us with", metadata={'source': 'transcription.txt'}),
#  Document(page_content="to surprise us with their power. Yeah, I think that's fair. So basically I'm underselling it by a", metadata={'source': 'transcription.txt'}),
#  Document(page_content='it by a lot because you definitely do get very surprising emergent behaviors out of these neural', metadata={'source': 'transcription.txt'}),
#  Document(page_content="out of these neural nets when they're large enough and trained on complicated enough problems. Like", metadata={'source': 'transcription.txt'}),
#  Document(page_content='problems. Like say, for example, the next word prediction in a massive data set from the internet.', metadata={'source': 'transcription.txt'}),
#  Document(page_content='from the internet. And then these neural nets take on pretty surprising magical properties. Yeah, I', metadata={'source': 'transcription.txt'}),
#  Document(page_content="properties. Yeah, I think it's kind of interesting how much you can get out of even very simple", metadata={'source': 'transcription.txt'}),
#  Document(page_content='of even very simple mathematical formalism. When your brain right now is talking, is it doing next', metadata={'source': 'transcription.txt'}),
#  Document(page_content="is it doing next word prediction? Or is it doing something more interesting? Well, it's definitely", metadata={'source': 'transcription.txt'}),
#  Document(page_content="it's definitely some kind of a generative model that's a GPT-like and prompted by you. Yeah, so", metadata={'source': 'transcription.txt'}),
#  Document(page_content="by you. Yeah, so you're giving me a prompt and I'm kind of like responding to it in a generative", metadata={'source': 'transcription.txt'}),
#  Document(page_content='it in a generative way. And by yourself, perhaps a little bit like are you adding extra prompts', metadata={'source': 'transcription.txt'}),
#  Document(page_content="extra prompts from your own memory inside your head? Or no? Well, definitely feels like you're", metadata={'source': 'transcription.txt'}),
#  Document(page_content="feels like you're referencing some kind of a declarative structure of like memory and so on. And", metadata={'source': 'transcription.txt'}),
#  Document(page_content="and so on. And then you're putting that together with your prompt and giving away some extra. How", metadata={'source': 'transcription.txt'}),
#  Document(page_content='some extra. How much of what you just said has been said by you before? Nothing, basically, right?', metadata={'source': 'transcription.txt'}),
#  Document(page_content="basically, right? No, but if you actually look at all the words you've ever said in your life and", metadata={'source': 'transcription.txt'}),
#  Document(page_content="in your life and you do a search, you'll probably said a lot of the same words in the same order", metadata={'source': 'transcription.txt'}),
#  Document(page_content="in the same order before. Yeah, could be. I mean, I'm using phrases that are common, etc. But I'm", metadata={'source': 'transcription.txt'}),
#  Document(page_content="etc. But I'm remixing it into a pretty sort of unique sentence at the end of the day. But you're", metadata={'source': 'transcription.txt'}),
#  Document(page_content="the day. But you're right, definitely, there's like a ton of remixing. Why you didn't, you just", metadata={'source': 'transcription.txt'}),
#  Document(page_content="didn't, you just like Magnus Carlson said, I'm rated 2,900, whatever, which is pretty decent. I", metadata={'source': 'transcription.txt'}),
#  Document(page_content="is pretty decent. I think you're talking very, you're not giving enough credit to neural nets here.", metadata={'source': 'transcription.txt'}),
#  Document(page_content="neural nets here. Why do they seem to, what's your best intuition about this emergent behavior? I", metadata={'source': 'transcription.txt'}),
#  Document(page_content="behavior? I mean, it's kind of interesting because I'm simultaneously underselling them. But I also", metadata={'source': 'transcription.txt'}),
#  Document(page_content="them. But I also feel like there's an element to which I'm over like, it's actually kind of", metadata={'source': 'transcription.txt'}),
#  Document(page_content='actually kind of incredible that you can get so much emergent magical behavior out of them, despite', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of them, despite them being so simple mathematically. So I think those are kind of like two', metadata={'source': 'transcription.txt'}),
#  Document(page_content='kind of like two surprising statements that are kind of just juxtaposed together. And I think', metadata={'source': 'transcription.txt'}),
#  Document(page_content='And I think basically what it is is we are actually fairly good at optimizing these neural nets.', metadata={'source': 'transcription.txt'}),
#  Document(page_content='these neural nets. And when you give them a hard enough problem, they are forced to learn very', metadata={'source': 'transcription.txt'}),
#  Document(page_content='to learn very interesting solutions in the optimization. And those solutions basically have these', metadata={'source': 'transcription.txt'}),
#  Document(page_content="have these emergent properties that are very interesting. There's wisdom and knowledge in the", metadata={'source': 'transcription.txt'}),
#  Document(page_content="knowledge in the knobs. And so this representation that's in the knobs doesn't make sense to you", metadata={'source': 'transcription.txt'}),
#  Document(page_content='make sense to you intuitively. The large number of knobs can hold a representation that captures', metadata={'source': 'transcription.txt'}),
#  Document(page_content="that captures some deep wisdom about the data. It has looked at a lot of knobs. It's a lot of", metadata={'source': 'transcription.txt'}),
#  Document(page_content="It's a lot of knobs. And somehow, so speaking concretely, one of the neural nets that people are", metadata={'source': 'transcription.txt'}),
#  Document(page_content='that people are very excited about right now are our GPs, which are basically just next word', metadata={'source': 'transcription.txt'}),
#  Document(page_content='just next word prediction networks. So you consume a sequence of words from the internet and you', metadata={'source': 'transcription.txt'}),
#  Document(page_content='internet and you try to predict the next word. And once you train these on a large enough data set,', metadata={'source': 'transcription.txt'}),
#  Document(page_content='enough data set, they you can basically prompt these neural nets in arbitrary ways and you can ask', metadata={'source': 'transcription.txt'}),
#  Document(page_content='and you can ask them to solve problems. And they will. So you can just tell them you can make it', metadata={'source': 'transcription.txt'}),
#  Document(page_content="you can make it look like you're trying to solve some kind of mathematical problem and they will", metadata={'source': 'transcription.txt'}),
#  Document(page_content="and they will continue what they think is the solution based on what they've seen on the internet.", metadata={'source': 'transcription.txt'}),
#  Document(page_content='on the internet. And very often those solutions look very remarkably consistent. Look correct', metadata={'source': 'transcription.txt'}),
#  Document(page_content='Look correct potentially. Do you still think about the brain side of it? So as neural nets is an', metadata={'source': 'transcription.txt'}),
#  Document(page_content='neural nets is an abstraction or mathematical abstraction of the brain, you still draw wisdom from', metadata={'source': 'transcription.txt'}),
#  Document(page_content='draw wisdom from the biological neural networks or even the bigger question. So your big fan of', metadata={'source': 'transcription.txt'}),
#  Document(page_content='So your big fan of biology and biological computation. What impressive thing is biology doing to', metadata={'source': 'transcription.txt'}),
#  Document(page_content="is biology doing to you the computer, not yet, the gap? I would say I'm definitely on a much more", metadata={'source': 'transcription.txt'}),
#  Document(page_content='on a much more hesitant with the analogies to the brain than I think he would see potentially in', metadata={'source': 'transcription.txt'}),
#  Document(page_content='see potentially in the field. And I kind of feel like certainly the way neural networks started is', metadata={'source': 'transcription.txt'}),
#  Document(page_content='networks started is everything stemmed from inspiration by the brain. But at the end of the day,', metadata={'source': 'transcription.txt'}),
#  Document(page_content='the end of the day, artifacts that you get after training, they are arrived at by a very different', metadata={'source': 'transcription.txt'}),
#  Document(page_content='by a very different optimization process than the optimization process that gave rise to the brain.', metadata={'source': 'transcription.txt'}),
#  Document(page_content="rise to the brain. And so I think I kind of think of it as a very complicated alien artifact. It's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="artifact. It's something different. I'm sorry, the neural nets that were training. They are", metadata={'source': 'transcription.txt'}),
#  Document(page_content='training. They are complicated alien artifact. I do not make analogies to the brain because I think', metadata={'source': 'transcription.txt'}),
#  Document(page_content='because I think the optimization process that gave rise to it is very different from the brain. So', metadata={'source': 'transcription.txt'}),
#  Document(page_content='from the brain. So there was no multi agent, self play kind of setup and evolution. It was an', metadata={'source': 'transcription.txt'}),
#  Document(page_content='It was an optimization that is basically a, what amounts to a compression objective on a massive', metadata={'source': 'transcription.txt'}),
#  Document(page_content='on a massive amount of data. Okay, so artificial neural networks are doing compression and', metadata={'source': 'transcription.txt'}),
#  Document(page_content="compression and biological neural networks. Now to survive. And I'm not really doing any of their,", metadata={'source': 'transcription.txt'}),
#  Document(page_content="doing any of their, they're an agent in a multi agent, self play system that's been running for", metadata={'source': 'transcription.txt'}),
#  Document(page_content='been running for very, very long time. That said, evolution has found that it is very useful to, to', metadata={'source': 'transcription.txt'}),
#  Document(page_content='very useful to, to predict and have a predictive model in the brain. And so I think our brain', metadata={'source': 'transcription.txt'}),
#  Document(page_content='I think our brain utilizes something that looks like that as a part of it. But it has a lot more,', metadata={'source': 'transcription.txt'}),
#  Document(page_content='it has a lot more, you know, catches and gizmos and value functions and ancient nuclei that are all', metadata={'source': 'transcription.txt'}),
#  Document(page_content='nuclei that are all trying to like make a survivor and reproduce and everything else. And the whole', metadata={'source': 'transcription.txt'}),
#  Document(page_content="else. And the whole thing through embryogenesis is built from a single cell. I mean, it's just the", metadata={'source': 'transcription.txt'}),
#  Document(page_content="mean, it's just the code is inside the DNA and it just builds it up like the entire organism with", metadata={'source': 'transcription.txt'}),
#  Document(page_content='organism with the sound. Crazy. And the head and legs. Yes. And like it does it pretty well. It', metadata={'source': 'transcription.txt'}),
#  Document(page_content="it pretty well. It should not be possible. So there's some learning going on. There's some, there's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="some, there's some, there's some kind of computation going through that building process. I mean, I", metadata={'source': 'transcription.txt'}),
#  Document(page_content="process. I mean, I don't know where, if you were just to look at the entirety of history of life on", metadata={'source': 'transcription.txt'}),
#  Document(page_content='history of life on Earth, what do you think is the most interesting invention? Is it the origin of', metadata={'source': 'transcription.txt'}),
#  Document(page_content='Is it the origin of life itself? Is it just jumping to eukaryotes? Is it mammals? Is it humans', metadata={'source': 'transcription.txt'}),
#  Document(page_content='Is it humans themselves, homo sapiens? Are the origin of intelligence or highly complex', metadata={'source': 'transcription.txt'}),
#  Document(page_content='or highly complex intelligence? Or is it all just a continuation of the same kind of process?', metadata={'source': 'transcription.txt'}),
#  Document(page_content="kind of process? Certainly, I would say it's an extremely remarkable story that I'm only like", metadata={'source': 'transcription.txt'}),
#  Document(page_content="that I'm only like briefly learning about recently. All the way from, actually, like, you almost", metadata={'source': 'transcription.txt'}),
#  Document(page_content='like, you almost have to start at the formation of Earth and all of its conditions and the entire', metadata={'source': 'transcription.txt'}),
#  Document(page_content='and the entire solar system and how everything is arranged with Jupiter and Moon and the habitable', metadata={'source': 'transcription.txt'}),
#  Document(page_content="and the habitable zone and everything. And then you have an active Earth that's turning over", metadata={'source': 'transcription.txt'}),
#  Document(page_content="that's turning over material. And then you start with a biogenesis and everything. And so it's all", metadata={'source': 'transcription.txt'}),
#  Document(page_content="And so it's all like a pretty remarkable story. I'm not sure that I can pick like a single unique", metadata={'source': 'transcription.txt'}),
#  Document(page_content='a single unique piece of it that I find most interesting. I guess for me as an artificial', metadata={'source': 'transcription.txt'}),
#  Document(page_content="me as an artificial intelligence researcher, it's probably the last piece. We have lots of animals", metadata={'source': 'transcription.txt'}),
#  Document(page_content='lots of animals that are not building technological society, but we do. And it seems to have', metadata={'source': 'transcription.txt'}),
#  Document(page_content='it seems to have happened very quickly. It seems to have happened very recently. And something very', metadata={'source': 'transcription.txt'}),
#  Document(page_content="And something very interesting happened there that I don't fully understand. I almost understand", metadata={'source': 'transcription.txt'}),
#  Document(page_content="I almost understand everything else, I think intuitively, but I don't understand exactly that part", metadata={'source': 'transcription.txt'}),
#  Document(page_content='exactly that part and how quick it was. Both explanations would be interesting. One is that this is', metadata={'source': 'transcription.txt'}),
#  Document(page_content="One is that this is just a continuation of the same kind of process. There's nothing special about", metadata={'source': 'transcription.txt'}),
#  Document(page_content='special about humans. That would be deeply understanding that would be very interesting. That we', metadata={'source': 'transcription.txt'}),
#  Document(page_content='That we think of ourselves as special, but it was obvious. All it was already written in the code', metadata={'source': 'transcription.txt'}),
#  Document(page_content='written in the code that you would have greater and greater intelligence emerging. And then the', metadata={'source': 'transcription.txt'}),
#  Document(page_content='And then the other explanation, which is something truly special happened, something like a rare', metadata={'source': 'transcription.txt'}),
#  Document(page_content="like a rare event, whether it's like crazy rare event, like space Odyssey. What would it be? See,", metadata={'source': 'transcription.txt'}),
#  Document(page_content='would it be? See, if you say like the invention of fire, or the, as Richard and Rangham says, the', metadata={'source': 'transcription.txt'}),
#  Document(page_content='Rangham says, the beta males deciding a clever way to kill the alpha males by collaborating. So', metadata={'source': 'transcription.txt'}),
#  Document(page_content='collaborating. So just optimizing the collaboration, the multi-agent aspect of the multi-agent. And', metadata={'source': 'transcription.txt'}),
#  Document(page_content='multi-agent. And that really being constrained on resources and trying to survive the collaboration', metadata={'source': 'transcription.txt'}),
#  Document(page_content="the collaboration aspect is what created the complex intelligence. But it seems like it's a natural", metadata={'source': 'transcription.txt'}),
#  Document(page_content="like it's a natural algorithm to the evolution process. What could possibly be a magical thing that", metadata={'source': 'transcription.txt'}),
#  Document(page_content='magical thing that happened? Like a rare thing that would say that humans are actually human level', metadata={'source': 'transcription.txt'}),
#  Document(page_content="human level intelligence, actually a really rare thing in the universe. Yeah, I'm hesitant to say", metadata={'source': 'transcription.txt'}),
#  Document(page_content="I'm hesitant to say that it is rare, by the way, but it definitely seems like it's kind of like a", metadata={'source': 'transcription.txt'}),
#  Document(page_content="it's kind of like a punctuated equilibrium where you have lots of exploration and then you have", metadata={'source': 'transcription.txt'}),
#  Document(page_content='and then you have certain leaps, sparse leaps in between. So of course, like origin of life would', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of life would be one, you know, DNA, sex, eukaryotic, eukaryotic life, the endosymbiosis event', metadata={'source': 'transcription.txt'}),
#  Document(page_content='endosymbiosis event where the archaeon ate the old bacteria, you know, just the whole thing. And', metadata={'source': 'transcription.txt'}),
#  Document(page_content='whole thing. And then of course, emergence of consciousness and so on. So it seems like definitely', metadata={'source': 'transcription.txt'}),
#  Document(page_content="like definitely there are sparse events where mass amount of progress was made. But yeah, it's kind", metadata={'source': 'transcription.txt'}),
#  Document(page_content="But yeah, it's kind of hard to pick one. So you don't think humans are unique. You've got to ask", metadata={'source': 'transcription.txt'}),
#  Document(page_content="You've got to ask you how many intelligent alien civilizations do you think are out there? And is", metadata={'source': 'transcription.txt'}),
#  Document(page_content="out there? And is there intelligence different or similar to ours? Yeah, I've been preoccupied with", metadata={'source': 'transcription.txt'}),
#  Document(page_content='preoccupied with this question quite a bit recently, basically the Fermi Paradox and just thinking', metadata={'source': 'transcription.txt'}),
#  Document(page_content='and just thinking through. And the reason actually that I am very interested in the origin of life', metadata={'source': 'transcription.txt'}),
#  Document(page_content='the origin of life is fundamentally trying to understand how common it is that there are', metadata={'source': 'transcription.txt'}),
#  Document(page_content='is that there are technological societies out there in space. And the more I study it, the more I', metadata={'source': 'transcription.txt'}),
#  Document(page_content="it, the more I think that there should be quite a lot. Why haven't we heard from them? Because I", metadata={'source': 'transcription.txt'}),
#  Document(page_content="them? Because I agree with you. It feels like I just don't see why what we did here and it's so", metadata={'source': 'transcription.txt'}),
#  Document(page_content="here and it's so difficult to do. Yeah, and especially when you get into the details of it, I used", metadata={'source': 'transcription.txt'}),
#  Document(page_content='of it, I used to think origin of life was very, it was this magical rare event, but then you read', metadata={'source': 'transcription.txt'}),
#  Document(page_content='but then you read books like, for example, in the claim, the vital question, life ascending, etc.', metadata={'source': 'transcription.txt'}),
#  Document(page_content='ascending, etc. And he really gets in and he really makes you believe that this is not that rare', metadata={'source': 'transcription.txt'}),
#  Document(page_content='is not that rare basic chemistry. You have an activist and you have your alkaline vents and you', metadata={'source': 'transcription.txt'}),
#  Document(page_content='vents and you have lots of alkaline waters, mixing with a devotion and you have your proton', metadata={'source': 'transcription.txt'}),
#  Document(page_content='have your proton gradients and you have the little porous pockets of these alkaline vents that', metadata={'source': 'transcription.txt'}),
#  Document(page_content='alkaline vents that concentrate chemistry. And basically as he steps through all of these little', metadata={'source': 'transcription.txt'}),
#  Document(page_content='all of these little pieces, you start to understand that actually this is not that crazy. You could', metadata={'source': 'transcription.txt'}),
#  Document(page_content='crazy. You could see this happen on other systems. And he really takes you from just a geology to', metadata={'source': 'transcription.txt'}),
#  Document(page_content="just a geology to primitive life and he makes it feel like it's actually pretty plausible. And also", metadata={'source': 'transcription.txt'}),
#  Document(page_content="plausible. And also like the origin of life didn't, was actually fairly fast after formation of", metadata={'source': 'transcription.txt'}),
#  Document(page_content="after formation of Earth. If I'm recurrently just a few hundred million years for something like", metadata={'source': 'transcription.txt'}),
#  Document(page_content='for something like that after basically when it was possible, life actually arose. And so that', metadata={'source': 'transcription.txt'}),
#  Document(page_content='arose. And so that makes me feel that that is not the constraint, that is not the limiting variable', metadata={'source': 'transcription.txt'}),
#  Document(page_content='limiting variable and that life should actually be fairly common. And then where the drop offs are', metadata={'source': 'transcription.txt'}),
#  Document(page_content="the drop offs are is very interesting to think about. I currently think that there's no major drop", metadata={'source': 'transcription.txt'}),
#  Document(page_content='no major drop offs basically and so there should be quite a lot of life. And basically where that', metadata={'source': 'transcription.txt'}),
#  Document(page_content="where that brings me to then is the only way to reconcile the fact that we haven't found anyone and", metadata={'source': 'transcription.txt'}),
#  Document(page_content="found anyone and so on is that we just can't see them. We can't observe them. Just a quick brief", metadata={'source': 'transcription.txt'}),
#  Document(page_content='Just a quick brief comment, Nick Lane and a lot of biologists I talked to, they really seem to', metadata={'source': 'transcription.txt'}),
#  Document(page_content='they really seem to think that the jump from bacteria to more complex organisms is the hardest', metadata={'source': 'transcription.txt'}),
#  Document(page_content="is the hardest jump. The you carry it like this. Yeah, which I don't, I get it, they're much more", metadata={'source': 'transcription.txt'}),
#  Document(page_content="they're much more knowledgeable than me about like the intricacies of biology. But that seems like", metadata={'source': 'transcription.txt'}),
#  Document(page_content='But that seems like crazy because how many single cell organisms are there? And how much time you', metadata={'source': 'transcription.txt'}),
#  Document(page_content="how much time you have, surely, it's not that difficult. Like an ability in years is not even that", metadata={'source': 'transcription.txt'}),
#  Document(page_content='is not even that long of a time really. Just all these bacteria under constrained resources', metadata={'source': 'transcription.txt'}),
#  Document(page_content="resources battling it out. I'm sure they can invent more complex. I don't understand. It's like how", metadata={'source': 'transcription.txt'}),
#  Document(page_content="It's like how to move from a hello world program to like invent a function or something like that.", metadata={'source': 'transcription.txt'}),
#  Document(page_content="like that. I don't yeah. So I don't, yeah, so I'm with you. I just feel like I don't see any. If", metadata={'source': 'transcription.txt'}),
#  Document(page_content="I don't see any. If the origin of life, that would be my intuition. That's the hardest thing. But", metadata={'source': 'transcription.txt'}),
#  Document(page_content="hardest thing. But if that's not the hardest thing because it happens so quickly, then it's got to", metadata={'source': 'transcription.txt'}),
#  Document(page_content="then it's got to be everywhere. And yeah, maybe we're just too dumb to see it. Well, it's just, we", metadata={'source': 'transcription.txt'}),
#  Document(page_content="Well, it's just, we don't have really good mechanisms for seeing this life. I mean, by what how? So", metadata={'source': 'transcription.txt'}),
#  Document(page_content="by what how? So I'm not an expert just to preface this, but just from I want to meet an expert on", metadata={'source': 'transcription.txt'}),
#  Document(page_content="meet an expert on alien intelligence and how to communicate. I'm very suspicious of our ability to", metadata={'source': 'transcription.txt'}),
#  Document(page_content='of our ability to to find these intelligence is out there and to find these Earth like radio waves,', metadata={'source': 'transcription.txt'}),
#  Document(page_content='like radio waves, for example, are terrible. Their power drops off as basically one over our', metadata={'source': 'transcription.txt'}),
#  Document(page_content='one over our square. So I remember reading that our current radio waves would not be the ones that', metadata={'source': 'transcription.txt'}),
#  Document(page_content='be the ones that we are broadcasting would not be measurable by our devices today. Only like, was', metadata={'source': 'transcription.txt'}),
#  Document(page_content='Only like, was it like one tenth of a light year away? Like not even basically tiny distance', metadata={'source': 'transcription.txt'}),
#  Document(page_content='tiny distance because you really need like a targeted transmission of massive power directed', metadata={'source': 'transcription.txt'}),
#  Document(page_content='power directed somewhere for this to be picked up on long long distances. And so I just think that', metadata={'source': 'transcription.txt'}),
#  Document(page_content="I just think that our ability to measure is is not amazing. I think there's probably other", metadata={'source': 'transcription.txt'}),
#  Document(page_content="probably other civilizations out there. And then the big question is why don't they build one", metadata={'source': 'transcription.txt'}),
#  Document(page_content="they build one element probes and why don't they interstellar travel across the entire galaxy? And", metadata={'source': 'transcription.txt'}),
#  Document(page_content="entire galaxy? And my current answer is it's probably interstellar travel is like really hard. You", metadata={'source': 'transcription.txt'}),
#  Document(page_content='really hard. You have the interstellar medium. If you want to move at close to speed of light,', metadata={'source': 'transcription.txt'}),
#  Document(page_content="to speed of light, you're going to be encountering bullets along the way because even like tiny", metadata={'source': 'transcription.txt'}),
#  Document(page_content='even like tiny hydrogen atoms and little particles of dust are basically have like massive kinetic', metadata={'source': 'transcription.txt'}),
#  Document(page_content='massive kinetic energy at those speeds. And so basically you need some kind of shielding. You need', metadata={'source': 'transcription.txt'}),
#  Document(page_content="shielding. You need that you have all the cosmic radiation. It's just like brutal out there. It's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="out there. It's really hard. And so my thinking is maybe interstellar travel is just extremely", metadata={'source': 'transcription.txt'}),
#  Document(page_content="is just extremely hard. I think you have to do it very slow. It feels like we're not a billion", metadata={'source': 'transcription.txt'}),
#  Document(page_content="we're not a billion years away from doing that. It just might be that it's very you have to go very", metadata={'source': 'transcription.txt'}),
#  Document(page_content='you have to go very slowly potentially as an example through space. Right. As opposed to close to', metadata={'source': 'transcription.txt'}),
#  Document(page_content="opposed to close to speed of light. So I'm suspicious basically of our ability to measure life. And", metadata={'source': 'transcription.txt'}),
#  Document(page_content="measure life. And I'm suspicious of the ability to just permeate all of space in the galaxy or", metadata={'source': 'transcription.txt'}),
#  Document(page_content="in the galaxy or across galaxies. And that's the only way that I can certainly see away around it.", metadata={'source': 'transcription.txt'}),
#  Document(page_content="see away around it. Yeah, it's kind of mind blowing. I think that there's trillions of intelligent", metadata={'source': 'transcription.txt'}),
#  Document(page_content='of intelligent alien civilizations out there kind of slowly traveling through space. Mm-hmm. Made', metadata={'source': 'transcription.txt'}),
#  Document(page_content='space. Mm-hmm. Made to meet each other and some of them meet some of them go to war some of them', metadata={'source': 'transcription.txt'}),
#  Document(page_content="to war some of them collaborate. Mm-hmm. Or they're all just independent. They general just like", metadata={'source': 'transcription.txt'}),
#  Document(page_content="general just like little pockets. Well, statistically if there's like if it's the trillions of them", metadata={'source': 'transcription.txt'}),
#  Document(page_content='trillions of them surely some of them some of the pockets are close enough to get some of them', metadata={'source': 'transcription.txt'}),
#  Document(page_content='to get some of them happen to be close. Yeah. And close enough to see each other. And then once you', metadata={'source': 'transcription.txt'}),
#  Document(page_content='And then once you see once you see something that is definitely complex life like if we see', metadata={'source': 'transcription.txt'}),
#  Document(page_content="life like if we see something. Yeah. We're probably going to be severe like intensely aggressively", metadata={'source': 'transcription.txt'}),
#  Document(page_content='aggressively motivated to figure out what the hell that is and try to meet them. Well, it will be', metadata={'source': 'transcription.txt'}),
#  Document(page_content='Well, it will be your first instinct to try to like at a generational level. Meet them or defend', metadata={'source': 'transcription.txt'}),
#  Document(page_content='Meet them or defend against them or it will be your instinct as a president of the United States.', metadata={'source': 'transcription.txt'}),
#  Document(page_content="the United States. And the scientist. I don't know which hat you prefer in this question. Yeah, I", metadata={'source': 'transcription.txt'}),
#  Document(page_content="question. Yeah, I think the question it's really hard. I will say like for example for us we have", metadata={'source': 'transcription.txt'}),
#  Document(page_content='for us we have lots of primitive life forms on earth. Next to us we have all kinds of ants and', metadata={'source': 'transcription.txt'}),
#  Document(page_content='kinds of ants and everything else and we share space with them. And we are hesitant to impact on', metadata={'source': 'transcription.txt'}),
#  Document(page_content='to impact on them and to we are trying to protect them by default because they are amazing', metadata={'source': 'transcription.txt'}),
#  Document(page_content='they are amazing interesting dynamical systems that took a long time to evolve and they are', metadata={'source': 'transcription.txt'}),
#  Document(page_content="evolve and they are interesting and special and I don't know that you want to destroy that by", metadata={'source': 'transcription.txt'}),
#  Document(page_content='to destroy that by default. And so I like complex dynamical systems that took a lot of time to', metadata={'source': 'transcription.txt'}),
#  Document(page_content="a lot of time to evolve. I think I'd like to preserve it if I can afford to. And I'd like to think", metadata={'source': 'transcription.txt'}),
#  Document(page_content="I'd like to think that the same would be true about the galactic resources and that they would", metadata={'source': 'transcription.txt'}),
#  Document(page_content="and that they would think that we're kind of incredible interesting story that took time. It took a", metadata={'source': 'transcription.txt'}),
#  Document(page_content="time. It took a few billion years to unravel and you don't want to just destroy it. I could see two", metadata={'source': 'transcription.txt'}),
#  Document(page_content="it. I could see two aliens talking about earth right now and saying I'm a big fan of complex", metadata={'source': 'transcription.txt'}),
#  Document(page_content="big fan of complex dynamical systems. So I think it's with a value to preserve these and we'll", metadata={'source': 'transcription.txt'}),
#  Document(page_content="these and we'll basically are a video game they watch or show a TV show that they watch. Yeah, I", metadata={'source': 'transcription.txt'}),
#  Document(page_content='they watch. Yeah, I think you would need like a very good reason I think to destroy it. Like why', metadata={'source': 'transcription.txt'}),
#  Document(page_content="it. Like why don't we destroy these ant farms and so on? It's because we're not actually like", metadata={'source': 'transcription.txt'}),
#  Document(page_content='not actually like really indirect competition with them right now. We do it accidentally and so on', metadata={'source': 'transcription.txt'}),
#  Document(page_content="and so on but there's plenty of resources. And so why would you destroy something that is so", metadata={'source': 'transcription.txt'}),
#  Document(page_content='that is so interesting and precious? Well, from a scientific perspective, you might probe it. You', metadata={'source': 'transcription.txt'}),
#  Document(page_content='might probe it. You might interact with it lately. Exactly. You might want to learn something from', metadata={'source': 'transcription.txt'}),
#  Document(page_content="something from it. So I wonder there's could be certain physical phenomena that we think is a", metadata={'source': 'transcription.txt'}),
#  Document(page_content="that we think is a physical phenomena but it's actually interacting with us to like poke the finger", metadata={'source': 'transcription.txt'}),
#  Document(page_content='poke the finger and see what happens. I think it should be very interesting to scientists. Other', metadata={'source': 'transcription.txt'}),
#  Document(page_content="scientists. Other alien scientists what happened here. And you know, it's a what we're seeing today", metadata={'source': 'transcription.txt'}),
#  Document(page_content="we're seeing today as a snapshot basically. It's a result of a huge amount of computation over like", metadata={'source': 'transcription.txt'}),
#  Document(page_content='over like billion years or something like that. So it could have been initiated by aliens. This', metadata={'source': 'transcription.txt'}),
#  Document(page_content='by aliens. This could be a computer running a program like when okay, if you had the power to do', metadata={'source': 'transcription.txt'}),
#  Document(page_content='had the power to do this, when you okay, for sure, at least I would, I would pick a earth-like', metadata={'source': 'transcription.txt'}),
#  Document(page_content='pick a earth-like planet that has the conditions based my understanding of the chemistry', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of the chemistry prerequisites for life. And I would see it with life and run it. Right? Like,', metadata={'source': 'transcription.txt'}),
#  Document(page_content="it. Right? Like, yeah, when you 100% do that and observe it and then protect, I mean, that's not", metadata={'source': 'transcription.txt'}),
#  Document(page_content="I mean, that's not just the hell of a good TV show. It's a good scientific experiment. And it's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="And it's physical simulation, right? Maybe the evolution is the most like actually running it is", metadata={'source': 'transcription.txt'}),
#  Document(page_content='running it is the most efficient way to understand computation or to compute stuff. For understand', metadata={'source': 'transcription.txt'}),
#  Document(page_content='For understand life or you know, what life looks like and what branches it can take. It does make', metadata={'source': 'transcription.txt'}),
#  Document(page_content="take. It does make me kind of feel weird there were part of a science experiment but maybe it's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="but maybe it's everything's a science experiment. Does that change anything for us? For a science", metadata={'source': 'transcription.txt'}),
#  Document(page_content="us? For a science experiment? I don't know. Two descendants of Apes talking about being inside of a", metadata={'source': 'transcription.txt'}),
#  Document(page_content="being inside of a science experiment. I'm suspicious of this idea of like a deliberate pens", metadata={'source': 'transcription.txt'}),
#  Document(page_content="a deliberate pens premiere as you described it. And I don't see a divine intervention in some way", metadata={'source': 'transcription.txt'}),
#  Document(page_content='in some way in the historical record right now. I do feel like the story in these books like', metadata={'source': 'transcription.txt'}),
#  Document(page_content="in these books like Nikolai's books and so on sort of makes sense and it makes sense how life arose", metadata={'source': 'transcription.txt'}),
#  Document(page_content="how life arose on earth uniquely. And yeah, I don't need a, I mean, I don't need to reach for more", metadata={'source': 'transcription.txt'}),
#  Document(page_content="to reach for more exotic explanations right now. Sure, but NPCs inside a video game don't don't", metadata={'source': 'transcription.txt'}),
#  Document(page_content="game don't don't observe any divine intervention either. We might just be all NPCs running a kind", metadata={'source': 'transcription.txt'}),
#  Document(page_content='NPCs running a kind of code. Maybe eventually they will. Currently, NPCs are really dumb but once', metadata={'source': 'transcription.txt'}),
#  Document(page_content="dumb but once they're running GPs, maybe they will be like, hey, this is really suspicious with the", metadata={'source': 'transcription.txt'}),
#  Document(page_content='suspicious with the hell. So you famously tweeted, it looks like if you bombard earth with photons', metadata={'source': 'transcription.txt'}),
#  Document(page_content="earth with photons for a while, you can emit a roaster. So if like an Hitchhiker's guide to the", metadata={'source': 'transcription.txt'}),
#  Document(page_content="guide to the galaxy, we would summarize the story of earth. So in that book it's mostly harmless.", metadata={'source': 'transcription.txt'}),
#  Document(page_content='mostly harmless. What do you think is all the possible stories, like a paragraph long or a sentence', metadata={'source': 'transcription.txt'}),
#  Document(page_content="long or a sentence long, that earth could be summarized as? At once it's done, it's computation. So", metadata={'source': 'transcription.txt'}),
#  Document(page_content='computation. So like all the possible full, if earth is a book, right? Yeah. Probably there has to', metadata={'source': 'transcription.txt'}),
#  Document(page_content="there has to be an ending. I mean, there's going to be an end to earth and it could end in all", metadata={'source': 'transcription.txt'}),
#  Document(page_content='it could end in all kinds of ways. It can end soon. It can end later. What do you think are the', metadata={'source': 'transcription.txt'}),
#  Document(page_content="you think are the possible stories? Well, definitely there seems to be, yeah, you're sort of, it's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="sort of, it's pretty incredible that the self-replicating systems will basically arise from the", metadata={'source': 'transcription.txt'}),
#  Document(page_content='arise from the dynamics and then they perpetuate themselves and become more complex and eventually', metadata={'source': 'transcription.txt'}),
#  Document(page_content="and eventually become conscious and build a society. And I kind of feel like in some sense it's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="in some sense it's kind of like a deterministic wave that kind of just happens on any sufficiently", metadata={'source': 'transcription.txt'}),
#  Document(page_content="on any sufficiently well-arranged system like earth. And so I kind of feel like there's a certain", metadata={'source': 'transcription.txt'}),
#  Document(page_content="there's a certain sense of inevitability in it. And it's really beautiful. And it ends somehow,", metadata={'source': 'transcription.txt'}),
#  Document(page_content="it ends somehow, right? So it's a chemically diverse environment where complex dynamical systems", metadata={'source': 'transcription.txt'}),
#  Document(page_content="dynamical systems can evolve and become more further further complex. But then there's a certain,", metadata={'source': 'transcription.txt'}),
#  Document(page_content="there's a certain, what is it? There's certain terminating conditions. Yeah, I don't know what the", metadata={'source': 'transcription.txt'}),
#  Document(page_content="don't know what the terminating conditions are, but definitely there's a trend line of something.", metadata={'source': 'transcription.txt'}),
# ...
#  Document(page_content='had to do with, for example, detection of objects and lane line markings and traffic lights and so', metadata={'source': 'transcription.txt'}),
#  Document(page_content="lights and so on. So you accumulate massive data sets of, here's an example, here's the desired", metadata={'source': 'transcription.txt'}),
#  Document(page_content="here's the desired label. And then here's roughly what the algorithm should look like, and that's a", metadata={'source': 'transcription.txt'}),
#  Document(page_content="like, and that's a completion on your own net. So the specification of the architecture is like a", metadata={'source': 'transcription.txt'}),
#  Document(page_content='is like a hint as to what the algorithm should roughly look like. And then the fill in the blanks', metadata={'source': 'transcription.txt'}),
#  Document(page_content='fill in the blanks process of optimization is the training process. And then you take your neural', metadata={'source': 'transcription.txt'}),
#  Document(page_content='take your neural net that was trained, it gives all the right answers on your data set and you', metadata={'source': 'transcription.txt'}),
#  Document(page_content="data set and you deploy it. So there's in that case, perhaps it all machine learning cases, there's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="cases, there's a lot of tasks. So is coming up formulating a task, like for a multi-headed neural", metadata={'source': 'transcription.txt'}),
#  Document(page_content='multi-headed neural network is formulating a task part of the programming. Yeah, very much so. How', metadata={'source': 'transcription.txt'}),
#  Document(page_content="very much so. How you break down a problem into a set of tasks. Yeah. I'm going to high level, I", metadata={'source': 'transcription.txt'}),
#  Document(page_content='to high level, I would say, if you look at the software running in the autopilot, I give a number', metadata={'source': 'transcription.txt'}),
#  Document(page_content='I give a number of talks on this topic. I would say originally a lot of it was written in software', metadata={'source': 'transcription.txt'}),
#  Document(page_content='written in software 1.0. There was, imagine lots of C++, right? And then gradually there was a tiny', metadata={'source': 'transcription.txt'}),
#  Document(page_content='there was a tiny neural net that was, for example, predicting given a single image, is there like a', metadata={'source': 'transcription.txt'}),
#  Document(page_content='is there like a traffic light or not, or is there a lane line marking or not? And this neural net', metadata={'source': 'transcription.txt'}),
#  Document(page_content="And this neural net didn't have too much to do in the scope of the software. It was making tiny", metadata={'source': 'transcription.txt'}),
#  Document(page_content='It was making tiny predictions on individual image. And then the rest of the system stitched it up.', metadata={'source': 'transcription.txt'}),
#  Document(page_content="stitched it up. So okay, we're actually, we don't have just a single camera with eight cameras. We", metadata={'source': 'transcription.txt'}),
#  Document(page_content='eight cameras. We actually have eight cameras over time. And so what do you do with these', metadata={'source': 'transcription.txt'}),
#  Document(page_content='you do with these predictions? How do you put them together? How do you do the fusion of all that', metadata={'source': 'transcription.txt'}),
#  Document(page_content='fusion of all that information and how do you act on it? All of that was written by humans in C++.', metadata={'source': 'transcription.txt'}),
#  Document(page_content="by humans in C++. And then we decided, okay, we don't actually want to do all of that fusion in C++", metadata={'source': 'transcription.txt'}),
#  Document(page_content="that fusion in C++ code because we're actually not good enough to write that algorithm. We want the", metadata={'source': 'transcription.txt'}),
#  Document(page_content='We want the neural net to write the algorithm. And we want to port all of that software into the', metadata={'source': 'transcription.txt'}),
#  Document(page_content='software into the 2.0 stack. And so then we actually had neural net that now take all the eight', metadata={'source': 'transcription.txt'}),
#  Document(page_content='take all the eight camera images simultaneously and make predictions for all of that. So, and', metadata={'source': 'transcription.txt'}),
#  Document(page_content="of that. So, and actually they don't make predictions in the space of images. They now make", metadata={'source': 'transcription.txt'}),
#  Document(page_content="They now make predictions directly in 3D. And actually they don't, in three dimensions around the", metadata={'source': 'transcription.txt'}),
#  Document(page_content="around the car. And now actually we don't manually fuse the predictions over in 3D over time. We", metadata={'source': 'transcription.txt'}),
#  Document(page_content="in 3D over time. We don't trust ourselves to write that tracker. So actually we give the neural net", metadata={'source': 'transcription.txt'}),
#  Document(page_content='give the neural net the information over time. So it takes these videos now and makes those', metadata={'source': 'transcription.txt'}),
#  Document(page_content="now and makes those predictions. And so you're starting just like putting more and more power into", metadata={'source': 'transcription.txt'}),
#  Document(page_content='and more power into the neural net, more and more processing. And at the end of it, the eventual', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of it, the eventual sort of goal is to have most of the software potentially be in the 2.0 land', metadata={'source': 'transcription.txt'}),
#  Document(page_content='be in the 2.0 land because it works significantly better. Humans are just not very good at writing', metadata={'source': 'transcription.txt'}),
#  Document(page_content='good at writing software, basically. So the prediction is happening in this like 4D land with three', metadata={'source': 'transcription.txt'}),
#  Document(page_content='4D land with three dimensional world over time. How do you do annotation in that world? So data', metadata={'source': 'transcription.txt'}),
#  Document(page_content="that world? So data annotation, whether it's self-supervised or manual by humans is a big part of", metadata={'source': 'transcription.txt'}),
#  Document(page_content="is a big part of the software 2.0 world. I would say by far in the industry, if you're like talking", metadata={'source': 'transcription.txt'}),
#  Document(page_content="you're like talking about the industry and how what is the technology of what we have available,", metadata={'source': 'transcription.txt'}),
#  Document(page_content='we have available, everything is supervised learning. So you need a data sets of input desired', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of input desired output and you need lots of it. And there are three properties of it that you', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of it that you need. You need it to be very large. You need it to be accurate, no mistakes, and you', metadata={'source': 'transcription.txt'}),
#  Document(page_content="mistakes, and you need it to be diverse. You don't want to just have a lot of correct examples of", metadata={'source': 'transcription.txt'}),
#  Document(page_content='correct examples of one thing. You need to really cover the space of possibility as much as you', metadata={'source': 'transcription.txt'}),
#  Document(page_content='as much as you can. And the more you can cover the space of possible inputs, the better the', metadata={'source': 'transcription.txt'}),
#  Document(page_content="the better the algorithm will work at the end. Now, once you have really good data sets that you're", metadata={'source': 'transcription.txt'}),
#  Document(page_content="sets that you're collecting, curating, and cleaning, you can train your neural net on top of that.", metadata={'source': 'transcription.txt'}),
#  Document(page_content='net on top of that. So a lot of the work goes into cleaning those data sets. Now, as you pointed', metadata={'source': 'transcription.txt'}),
#  Document(page_content="Now, as you pointed out, it's probably, it could be the question is, how do you achieve a ton of,", metadata={'source': 'transcription.txt'}),
#  Document(page_content='achieve a ton of, if you want to basically predict in 3D, you need data in 3D to back that up. So', metadata={'source': 'transcription.txt'}),
#  Document(page_content='to back that up. So in this video, we have eight videos coming from all the cameras of the system.', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of the system. And this is what they saw. And this is the truth of what actually was around. There', metadata={'source': 'transcription.txt'}),
#  Document(page_content='was around. There was this car, there was this car, this car, these are the lane line markings.', metadata={'source': 'transcription.txt'}),
#  Document(page_content='lane line markings. This is geometry of the road. There is traffic light in this redimensional', metadata={'source': 'transcription.txt'}),
#  Document(page_content='this redimensional position. You need the ground truth. And so the big question that team was', metadata={'source': 'transcription.txt'}),
#  Document(page_content='that team was solving, of course, is how do you, how do you arrive at that ground truth? Because', metadata={'source': 'transcription.txt'}),
#  Document(page_content="truth? Because once you have a million of it, and it's large, clean, and diverse, then training a", metadata={'source': 'transcription.txt'}),
#  Document(page_content='then training a neural net on it works extremely well. And you can ship that into the car. And so', metadata={'source': 'transcription.txt'}),
#  Document(page_content="the car. And so there's many mechanisms by which we collected that training data. You can always go", metadata={'source': 'transcription.txt'}),
#  Document(page_content='You can always go for a human annotation. You can go for simulation as a source of grunt truth. You', metadata={'source': 'transcription.txt'}),
#  Document(page_content='of grunt truth. You can also go for what we call the offline tracker that we spoken about at the AI', metadata={'source': 'transcription.txt'}),
#  Document(page_content='about at the AI day and so on, which is basically an automatic reconstruction process for taking', metadata={'source': 'transcription.txt'}),
#  Document(page_content='process for taking those videos and recovering the three-dimensional sort of reality of what was', metadata={'source': 'transcription.txt'}),
#  Document(page_content='reality of what was around that car. So basically think of doing like a three-dimensional', metadata={'source': 'transcription.txt'}),
#  Document(page_content="a three-dimensional reconstruction as an offline thing. And then understanding that, okay, there's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="that, okay, there's 10 seconds of video. This is what we saw. And therefore, here's all the lane", metadata={'source': 'transcription.txt'}),
#  Document(page_content="here's all the lane lines cars and so on. And then once you have that annotation, you can train", metadata={'source': 'transcription.txt'}),
#  Document(page_content="you can train your neural nets to imitate it. And how difficult is the reconstruction? It's", metadata={'source': 'transcription.txt'}),
#  Document(page_content="It's difficult. But it can be done. So there's the overlap between the cameras and you do the", metadata={'source': 'transcription.txt'}),
#  Document(page_content="and you do the reconstruction. And there's perhaps there's any inaccuracy. So that's caught in the", metadata={'source': 'transcription.txt'}),
#  Document(page_content='caught in the annotation step. Yes, the nice thing about the annotation is that it is fully', metadata={'source': 'transcription.txt'}),
#  Document(page_content="is that it is fully offline. You have infinite time. You have a chunk of one minute and you're", metadata={'source': 'transcription.txt'}),
#  Document(page_content="minute and you're trying to just offline in a supercomputer somewhere, figure out where were the", metadata={'source': 'transcription.txt'}),
#  Document(page_content='out where were the positions of all the cars, all the people. And you have your full one minute', metadata={'source': 'transcription.txt'}),
#  Document(page_content='full one minute video from all the angles. And you can run all the neural nets you want and they', metadata={'source': 'transcription.txt'}),
#  Document(page_content="you want and they can be very efficient, massive neural nets. There can be neural nets that can't", metadata={'source': 'transcription.txt'}),
#  Document(page_content="nets that can't even run in the car later at test time. So they can be even more powerful neural", metadata={'source': 'transcription.txt'}),
#  Document(page_content='powerful neural nets than what you can eventually deploy. So you can do anything you want, three', metadata={'source': 'transcription.txt'}),
#  Document(page_content='you want, three dimensional reconstruction, neural nets, anything you want just to recover that', metadata={'source': 'transcription.txt'}),
#  Document(page_content='to recover that truth. And then you supervise that truth. What have you learned? You said no', metadata={'source': 'transcription.txt'}),
#  Document(page_content="You said no mistakes about humans doing annotation. Because I assume humans there's like a range of", metadata={'source': 'transcription.txt'}),
#  Document(page_content="like a range of things they're good at in terms of clicking stuff on screen. Isn't that how", metadata={'source': 'transcription.txt'}),
#  Document(page_content="Isn't that how interesting is that you have a problem with designing an annotator or humans are", metadata={'source': 'transcription.txt'}),
#  Document(page_content='or humans are accurate, enjoy it. Like what are they even the metrics or efficient or productive,', metadata={'source': 'transcription.txt'}),
#  Document(page_content='or productive, all that kind of stuff? Yeah. So I grew the annotation team at Tesla from basically', metadata={'source': 'transcription.txt'}),
#  Document(page_content='from basically zero to a thousand while I was there. That was really interesting. You know, my', metadata={'source': 'transcription.txt'}),
#  Document(page_content='You know, my background is a PhD student researcher. So growing that common organization was pretty', metadata={'source': 'transcription.txt'}),
#  Document(page_content="was pretty crazy. But yeah, I think it's extremely interesting and part of the design process very", metadata={'source': 'transcription.txt'}),
#  Document(page_content='design process very much behind the autopilot as to where you use humans. Humans are very good at', metadata={'source': 'transcription.txt'}),
#  Document(page_content="are very good at certain kinds of annotations. They're very good, for example, at two-dimensional", metadata={'source': 'transcription.txt'}),
#  Document(page_content="at two-dimensional annotations of images. They're not good at annotating cars over time in", metadata={'source': 'transcription.txt'}),
#  Document(page_content="cars over time in three-dimensional space, very, very hard. And so that's why we were very careful", metadata={'source': 'transcription.txt'}),
#  Document(page_content='were very careful to design the tasks that are easy to do for humans versus things that should be', metadata={'source': 'transcription.txt'}),
#  Document(page_content='that should be left to the offline tracker. Like maybe the computer will do older triangulation in', metadata={'source': 'transcription.txt'}),
#  ...]

# %% [markdown]
# ## Similarity Search

# %%
from langchain_community.embeddings.ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings()
embedded_query = embeddings.aembed_query("Who is Mary's sister?")


# print(f"Embedding length: {len(embedded_query)}")
# print(embedded_query[:10])
# Out:
# /var/folders/rw/4k88jv4x315d2kjjqyn8hhgc0000gn/T/ipykernel_50103/3782317449.py:4: RuntimeWarning: coroutine 'Embeddings.aembed_query' was never awaited
#   embedded_query = embeddings.aembed_query("Who is Mary's sister?")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 7
#       3 embeddings = OllamaEmbeddings()
#       4 embedded_query = embeddings.aembed_query("Who is Mary's sister?")
# ----> 7 embedded_query.__len__
#       8 # print(f"Embedding length: {len(embedded_query)}")
#       9 # print(embedded_query[:10])
#
# AttributeError: 'coroutine' object has no attribute '__len__'

# %%
str (46546)
# Out:
# '46546'
